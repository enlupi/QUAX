# %% [markdown]
# # Single Run Analysis
#
# Notebook presenting the complete analysis for a single run (run 395).

# %%
import nbimporter
import prepData as prep
import fitFunc as fits
import Statistics as stat

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Table of Contents
#
# 1. [Load Dataset](#load) <br>
# 2. [Preliminary Fits](#fits) <br>
#     2.1. [Backgroun Fit](#fits_bkg) <br>
#     2.2. [Signal Fit](#fits_sig) <br>
# 3. [Statistical Analysis](#stats) <br>
#     3.1. [Significance](#stats_sign) <br>
#     3.2. [Confidence Interval](#stats_ci) <br>

# %% [markdown]
# ## 1. Load Dataset <a name="load"></a>
#
# Load data and prepare it for further analysis using code defined in the "prepData" notebook.

# %%
data,center,length = prep.load_dataset(395)
freq, fft, weights, ref, N = prep.prep_data(data,center, length=length)
# Out:
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(freq, fft)
plt.xlabel('Frequence [Hz]')
plt.ylabel('FFT')
# Out:
# Text(0, 0.5, 'FFT')

# %% [markdown]
# ## 2. Preliminary Fits <a name="fits"></a>

# %% [markdown]
# ### 2.1. Background Fit <a name="fits_bkg"></a>
#
# As a preliminary check, we will fit the background function
#
# $$exp \left( 2 \cdot \frac{|x - a+ib|^2}{|x - c+id|^2} + f \cdot (x - c) \right)$$
#
# and study the distribution of residuals.

# %%
res_bkg = fits.fit_bkg(freq, fft, weights, center, ref)
fits.plot_fit(freq, fft, weights, res_bkg)
# Out:
# <h2> Model</h2> Model(bkg) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>43</td><td></td></tr><tr><td># data points</td><td>200</td><td></td></tr><tr><td># variables</td><td>6</td><td></td></tr><tr><td>chi-square</td><td> 192.902587</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.99434323</td><td></td></tr><tr><td>Akaike info crit.</td><td> 4.77359296</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 24.5634972</td><td></td></tr><tr><td>R-squared</td><td> 0.99999926</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a </td><td>  1.0353e+10 </td><td>  102.071928 </td><td> (0.00%) </td><td> 10353468841.0 </td><td>  1.0343e+10 </td><td>  1.0457e+10 </td><td> True </td></tr><tr><td> b </td><td>  20070.3629 </td><td>  83.9638639 </td><td> (0.42%) </td><td> 20000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> c </td><td>  1.0353e+10 </td><td>  110.767871 </td><td> (0.00%) </td><td> 10353468841.0 </td><td>  1.0343e+10 </td><td>  1.0457e+10 </td><td> True </td></tr><tr><td> d </td><td>  21269.0631 </td><td>  89.0844926 </td><td> (0.42%) </td><td> 22000.0 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> e </td><td>  188.075033 </td><td>  0.01736948 </td><td> (0.01%) </td><td> 264.0396645903837 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> f </td><td> -0.00649517 </td><td>  1.9076e-04 </td><td> (2.94%) </td><td> 0.0006971694447700232 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>b</td><td>d</td><td>+0.9997</td></tr><tr><td>a</td><td>c</td><td>+0.9996</td></tr><tr><td>c</td><td>f</td><td>-0.8429</td></tr><tr><td>a</td><td>f</td><td>-0.8297</td></tr><tr><td>d</td><td>e</td><td>+0.7144</td></tr><tr><td>b</td><td>e</td><td>+0.7007</td></tr><tr><td>b</td><td>c</td><td>+0.3657</td></tr><tr><td>b</td><td>f</td><td>-0.3627</td></tr><tr><td>a</td><td>b</td><td>+0.3608</td></tr><tr><td>c</td><td>d</td><td>+0.3601</td></tr><tr><td>d</td><td>f</td><td>-0.3583</td></tr><tr><td>a</td><td>d</td><td>+0.3553</td></tr><tr><td>a</td><td>e</td><td>-0.1551</td></tr><tr><td>c</td><td>e</td><td>-0.1508</td></tr></table>

# %% [markdown]
# ### 2.1. Signal Fit <a name="fits_sig"></a>
#
# We will now fit the data with a gaussian signal over the background
#
# $$\mu \cdot exp \left( -\frac{1}{2} \frac{(x - x_0)^2}{\sigma^2} \right)$$
#
# using every possible frequency as the centre of the signal $x_0$.

# %%
bkg_params = res_bkg.best_values

mu_fit = np.empty(len(freq))
for i in range(len(freq)):
    res_sig = fits.fit_sig(x=freq, y=fft, w=weights, x_0=freq[i],
                           init_params=bkg_params, signal=fits.signal_gauss, par_vary=False)
    mu_fit[i] = res_sig.best_values["mu"]

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(freq, mu_fit)
plt.xlabel(r'$x_0$ [Hz]')
plt.ylabel(r'$\hat{\mu}$')
# Out:
# Text(0, 0.5, '$\\hat{\\mu}$')

# %% [markdown]
# Let us now check the goodness of the fits, using the one returning the maximum $\hat{\mu}$ as an example.

# %%
x0_max = freq[np.argmax(mu_fit)]

res_sig = fits.fit_sig(x=freq, y=fft, w=weights, x_0=x0_max,
                       init_params=bkg_params, signal=fits.signal_gauss, par_vary=False)
fits.plot_fit(freq, fft, weights, res_sig)
# Out:
# <h2> Model</h2> Model(signal_gauss) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>7</td><td></td></tr><tr><td># data points</td><td>200</td><td></td></tr><tr><td># variables</td><td>1</td><td></td></tr><tr><td>chi-square</td><td> 192.802779</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.96885819</td><td></td></tr><tr><td>Akaike info crit.</td><td>-5.32991362</td><td></td></tr><tr><td>Bayesian info crit.</td><td>-2.03159626</td><td></td></tr><tr><td>R-squared</td><td> 0.99999926</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a </td><td>  1.0353e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 10353468601.731169 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> b </td><td>  20070.3629 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 20070.362875535502 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> c </td><td>  1.0353e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 10353468691.596733 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> d </td><td>  21269.0631 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 21269.063148061265 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> e </td><td>  188.075033 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 188.07503303460376 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> f </td><td> -0.00649517 </td><td>  0.00000000 </td><td> (0.00%) </td><td> -0.006495168594883054 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> x0 </td><td>  1.0353e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 10353409505.208334 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> s </td><td>  10416.0000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 10416 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> mu </td><td>  2.02836535 </td><td>  6.31965084 </td><td> (311.56%) </td><td> 1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table>

# %% [markdown]
# It is important to note that, if you let every parameter vary, the fit does not converge for $\mu$ and it gets stuck on the starting value.

# %%
res_sig = fits.fit_sig(x=freq, y=fft, w=weights, x_0=x0_max,
                       init_params=bkg_params, signal=fits.signal_gauss, par_vary=True, mu_init=0.1)
fits.plot_fit(freq, fft, weights, res_sig)
# Out:
# <h2> Model</h2> Model(signal_gauss) <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>9</td><td></td></tr><tr><td># data points</td><td>200</td><td></td></tr><tr><td># variables</td><td>7</td><td></td></tr><tr><td>chi-square</td><td> 192.892988</td><td></td></tr><tr><td>reduced chi-square</td><td> 0.99944554</td><td></td></tr><tr><td>Akaike info crit.</td><td> 6.76364096</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 29.8518625</td><td></td></tr><tr><td>R-squared</td><td> 0.99999926</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a </td><td>  1.0353e+10 </td><td>  4.90558747 </td><td> (0.00%) </td><td> 10353468601.731169 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> b </td><td>  20070.3629 </td><td>  124.958756 </td><td> (0.62%) </td><td> 20070.362875535502 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> c </td><td>  1.0353e+10 </td><td>  31.6802073 </td><td> (0.00%) </td><td> 10353468691.596733 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> d </td><td>  21269.0631 </td><td>  130.545551 </td><td> (0.61%) </td><td> 21269.063148061265 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> e </td><td>  188.075033 </td><td>  0.03763623 </td><td> (0.02%) </td><td> 188.07503303460376 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> f </td><td> -0.00649517 </td><td>  2.9972e-04 </td><td> (4.61%) </td><td> -0.006495168594883054 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> x0 </td><td>  1.0353e+10 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 10353409505.208334 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> s </td><td>  10416.0000 </td><td>  0.00000000 </td><td> (0.00%) </td><td> 10416 </td><td>        -inf </td><td>         inf </td><td> False </td></tr><tr><td> mu </td><td>  0.10000000 </td><td>  21.1004970 </td><td> (21100.50%) </td><td> 0.1 </td><td>  0.00000000 </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>b</td><td>d</td><td>+0.9951</td></tr><tr><td>a</td><td>f</td><td>+0.9227</td></tr><tr><td>e</td><td>mu</td><td>-0.8876</td></tr><tr><td>b</td><td>e</td><td>+0.8118</td></tr><tr><td>f</td><td>mu</td><td>+0.8111</td></tr><tr><td>d</td><td>e</td><td>+0.7761</td></tr><tr><td>a</td><td>mu</td><td>+0.7401</td></tr><tr><td>e</td><td>f</td><td>-0.7103</td></tr><tr><td>a</td><td>e</td><td>-0.6812</td></tr><tr><td>c</td><td>f</td><td>-0.6641</td></tr><tr><td>b</td><td>mu</td><td>-0.6159</td></tr><tr><td>d</td><td>mu</td><td>-0.5680</td></tr><tr><td>a</td><td>c</td><td>-0.4985</td></tr><tr><td>a</td><td>b</td><td>-0.4100</td></tr><tr><td>c</td><td>d</td><td>-0.3583</td></tr><tr><td>b</td><td>f</td><td>-0.3228</td></tr><tr><td>a</td><td>d</td><td>-0.3210</td></tr><tr><td>b</td><td>c</td><td>-0.2874</td></tr><tr><td>c</td><td>mu</td><td>-0.2541</td></tr><tr><td>d</td><td>f</td><td>-0.2385</td></tr><tr><td>c</td><td>e</td><td>+0.1722</td></tr></table>

# %% [markdown]
# ## 3. Statistical Analysis <a name="stats"></a>

# %% [markdown]
# ### 3.1. Significance <a name="stats_sign"></a>
#
# Assuming the presence of a signal, we will now compute its significance. As more thoroughly explained in the "Statistics" notebook, this quantity is computed from the p-value of the observed likelihood ratio
#
# $$q_0^{obs} = -2 \cdot \log \left( \cfrac{\mathcal{L} \left(Data | 0, \hat{\theta}_0 \right)}{\mathcal{L} \left(Data | \hat{\mu}, \hat{\theta}_\hat{\mu} \right)}\right)$$
#
# with respect to a distribution ob of $q_0$ obtained from toy datasets.
# Every recorded frequency is investigated as a possible center of the signal, $x_0$.

# %%
z_tot, _ = stat.stat_test(run=395, x_0=freq, mu_fix=0,
                          signal=fits.signal_gauss, n_toy=1000,
                          calc_z=True, calc_CI=False, draw=False, verbose=False, path='db/')
# Out:
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2
# Step: 20
# Step: 40
# Step: 60
# Step: 80
# Step: 100
# Step: 120
# Step: 140
# Step: 160
# Step: 180
# Step: 200

# %%
fig = plt.figure(figsize=(8, 4))
plt.plot(freq, z_tot)
plt.xlabel(r'$x_0$ [Hz]')
plt.ylabel('Significance')

max_z = np.max(z_tot)
freq_max_z = freq[z_tot == max_z].values

print("The highest significance is", round(max_z, 2), "found at", freq_max_z[0], "Hz")
# Out:
# The highest significance is 1.32 found at 10353412109.375 Hz

# %%
print(z_tot)
# Out:
# [ 6.65078946e-01  7.32276205e-01  8.20379146e-01  9.15365088e-01
#   9.42376333e-01  1.01522203e+00  1.07583736e+00  1.15034938e+00
#   1.22652812e+00  1.27023762e+00  1.29303198e+00  1.30468539e+00
#   1.32250514e+00  1.30468539e+00  1.28155157e+00  1.22652812e+00
#   1.13589622e+00  1.06693763e+00  9.66088297e-01  8.45198535e-01
#   7.03089460e-01  5.62170292e-01  4.42676144e-01  3.61133034e-01
#   2.22403227e-01  1.30715968e-01  3.00840766e-02 -1.05374430e+00
#  -3.98855066e-01 -2.40426031e-01 -7.85773832e-01 -6.46431416e-01
#  -1.38304208e-01 -9.74113877e-01 -1.67466489e+00 -3.34503036e-01
#  -1.38304208e-01 -3.37155077e-01 -1.08031934e+00 -5.82841507e-01
#  -1.86567182e-01 -2.19834564e-01 -3.02855481e-01 -2.09574223e-01
#  -8.53287949e-02 -5.04371986e-01 -9.46291358e-01 -3.82622075e-01
#  -6.00759774e-01 -2.40891555e+00 -6.87131287e-01 -1.38517161e+00
#  -4.93017814e-01 -1.79911811e+00 -1.27587418e+00 -4.45442506e-01
#  -1.04504970e+00 -5.68051498e-01 -3.45125531e-01 -2.30118101e-01
#   4.01168102e-02  1.50969215e-01  2.09574223e-01  2.87146694e-01
#   3.79926467e-01  4.48212281e-01  4.98686864e-01  5.38836030e-01
#   5.68051498e-01  6.06775364e-01  6.40265509e-01  6.46431416e-01
#   6.46431416e-01  6.46431416e-01  6.31061979e-01  6.06775364e-01
#   5.88793212e-01  5.76910377e-01  5.65108452e-01  5.41736560e-01
#   5.10073457e-01  4.67698799e-01  4.45442506e-01  3.82622075e-01
#   3.18639364e-01  2.84535543e-01  2.24973358e-01  1.89118426e-01
#   1.07994569e-01  4.51346285e-02  1.25334695e-02 -2.75764057e-02
#  -1.13038541e-01 -1.25661347e-01 -2.19834564e-01 -6.09791399e-01
#  -9.46291358e-01 -5.18656932e-01 -5.53384720e-01 -1.03215396e+00
#  -5.65108452e-01 -3.79926467e-01 -3.05480788e-01 -2.37846695e-01
#  -1.00433721e-01  2.75764057e-02  1.20609934e-01  2.01893479e-01
#   2.87146694e-01  3.21277640e-01  4.07010876e-01  4.50985499e-01
#   4.84543782e-01  4.95850347e-01  5.21526572e-01  5.33048511e-01
#   5.53384720e-01  5.56308467e-01  5.88793212e-01  6.21911596e-01
#   6.28006014e-01  6.37191675e-01  6.37191675e-01  6.40265509e-01
#   6.43345405e-01  6.06775364e-01  5.76910377e-01  5.12930411e-01
#   4.87364565e-01  4.28894504e-01  3.98855066e-01  3.61133034e-01
#   3.00232259e-01  2.55936332e-01  1.89118426e-01  1.07994569e-01
#   5.51738021e-02 -2.50663090e-03 -5.82841507e-01 -1.03215396e+00
#  -2.29036788e+00 -8.92733324e-01 -3.50451343e-01 -5.18656932e-01
#  -7.75574943e-01 -7.06302563e-01 -1.43250272e+00 -5.12930411e-01
#  -1.53505060e-01 -4.37153541e-01 -8.38054670e-01 -1.29303198e+00
#  -9.94457883e-01 -1.71688602e+00 -1.67466489e+00 -1.68494077e+00
#  -1.76241030e+00 -6.03764838e-01 -1.81191067e+00 -6.31061979e-01
#  -5.50465695e-01 -6.40265509e-01 -1.44663207e+00 -1.34075503e+00
#  -9.46291358e-01 -5.85814766e-01 -2.12137198e-01 -4.76439560e-02
#  -3.23918153e-01 -1.02365131e+00 -2.74778139e+00 -6.52185397e-02
#  -1.06251930e+00 -9.42376333e-01 -2.09692743e+00 -8.70549830e-01
#  -3.05480788e-01  2.50689083e-02  1.10516204e-01  1.30715968e-01
#   1.78920660e-01  2.63714398e-01  3.45125531e-01  4.04289290e-01
#   4.59326111e-01  4.98686864e-01  5.65108452e-01  6.00759774e-01
#   6.37191675e-01  6.77639965e-01  6.93493346e-01  6.99883600e-01
#   6.87131287e-01  6.87131287e-01  6.58837693e-01  6.46431416e-01
#   6.24955903e-01  6.03764838e-01  5.94765847e-01  5.65108452e-01]

# %% [markdown]
# The highest significance found is too small to refute the *background-only* hypothesis.

# %% [markdown]
# Here are three examples of the likelihood ratio distribution obtained from toy data for different choices of $x_0$:
#
# - the frequency corresponding to the maximum value of $\hat{\mu}$
# - the center of the cavity
# - a secondary peak of $\hat{\mu}$

# %%
z_example, _ = stat.stat_test(run=395, x_0=[x0_max, center, freq[116]], mu_fix=0,
                              signal=fits.signal_gauss, n_toy=1000,
                              calc_z=True, calc_CI=False, draw=True, verbose=False, path='db/')
# Out:
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2

# %% [markdown]
# ### 3.2. Confidence Interval <a name="stats_ci"></a>
#
# We are now interested in setting a limit on the strength of the signal, thus computing $\mu^{95\% CL}$. It would not be correct *a priori* to do both this and the previous staistical test, as they start from different assumptions on the presence of the signal or lack thereof; we will still be showing both for a more complete discussion.
#
# Due to computational constraints, $\mu^{95\% CL}$ is computed by scanning values of $\mu$ with a step of $\Delta \mu = 5$ and taking 1 in every 5 bins as a possible $x_0$. Given that the expected standard deviation of the signal is 14 bins, it is still an acceptable level of precision.

# %%
_, muCI_tot = stat.stat_test(run=395, x_0=freq[range(0, 200, 5)].values, mu_fix=60,
                             signal=fits.signal_gauss, n_toy=1000,
                             calc_z=False, calc_CI=True, draw=False, verbose=False, path='db/')
# Out:
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2
# Step: 20
# Step: 40

# %%
fig = plt.figure(figsize=(8, 4))
plt.scatter(freq[range(0, 200, 5)].values, muCI_tot, marker='o')
plt.plot(freq[range(0, 200, 5)].values, muCI_tot, linestyle='dashed', color="black", linewidth=0.5)
plt.xlabel(r'$x_0$ [Hz]')
plt.ylabel(r'$\mu^{95\%CL}$')
# Out:
# Text(0, 0.5, '$\\mu^{95\\%CL}$')

# %%
print(muCI_tot)
# Out:
# [ 50.  60.  70.  65.  45.  30.  25.  20.  20.  20.  25.  30.  45.  55.
#   65.  70.  75.  85. 100.  90.  75. 100. 100.  95.  75.  65.  60.  50.
#   40.  30.  25.  20.  20.  20.  25.  30.  40.  55.  55.  50.]

# %% [markdown]
# As for the previous test, we will now show some examples of the distributions of the likelihood ratio
#
# $$q^{obs} \left( \mu \right) = -2 \cdot \log \left( \cfrac{\mathcal{L} \left(Data | \mu, \hat{\theta}_{\mu} \right)}{\mathcal{L} \left(Data | \hat{\mu}, \hat{\theta}_\hat{\mu} \right)}\right)$$
#
# used to compute $\mu^{95\% CL}$, from toy datasets obtained both from *background-only* and *background+signal* hypotheses. Forsimplicity, the choice of $x_0$ will be the same of before.

# %%
_, muCI_example1 = stat.stat_test(run=395, x_0=[x0_max], mu_fix=60,
                                  signal=fits.signal_gauss, n_toy=1000,
                                  calc_z=False, calc_CI=True, draw=True, verbose=True, path='db/')
_, muCI_example2 = stat.stat_test(run=395, x_0=[center], mu_fix=80,
                                  signal=fits.signal_gauss, n_toy=1000,
                                  calc_z=False, calc_CI=True, draw=True, verbose=True, path='db/')
_, muCI_example3 = stat.stat_test(run=395, x_0=[freq[116]], mu_fix=95,
                                  signal=fits.signal_gauss, n_toy=1000,
                                  calc_z=False, calc_CI=True, draw=True, verbose=True, path='db/')
# Out:
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2
# Mu:  60    q(mu)_obs = 81.07271738420968
# p_mu = 0.054   p_b = 0.863   ratio = 0.06257242178447277
#
# Mu:  65.0    q(mu)_obs = 95.65882482989855
# p_mu = 0.037   p_b = 0.863   ratio = 0.04287369640787949
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2
# Mu:  80    q(mu)_obs = 243.40080667938014
# p_mu = 0.013   p_b = 0.312   ratio = 0.041666666666666664
# Dataset loaded: db/AnalyzedDataFFT_Run_395_sliced.xlsx
# Cavity frequency: 10353468841.0 Hz
# fft subrun:2
# Mu:  95    q(mu)_obs = 327.7419683283117
# p_mu = 0.02   p_b = 0.721   ratio = 0.027739251040221916
#
# Mu:  90.0    q(mu)_obs = 294.0667802114465
# p_mu = 0.028   p_b = 0.721   ratio = 0.03883495145631068
#
# Mu:  85.0    q(mu)_obs = 262.2088826391662
# p_mu = 0.032   p_b = 0.719   ratio = 0.044506258692628656
